# %% [markdown]
# ## **Servo Prediction using Linear Regression**

# %% [markdown]
# # **What is Servo**
#
#  In control engineering a servomechanism, usually shortened to servo, is an automatic device that uses error-sensing negative feedback to correct the action of a mechanism. On displacement-controlled applications, it usually includes a built-in encoder or other position feedback mechanism to ensure the output is achieving the desired effect.
#
#   The term correctly applies only to systems where the feedback or error-correction signals help control mechanical position, speed, attitude or any other measurable variables.
#
#   For example, an automotive power window control is not a servomechanism, as there is no automatic feedback that controls position-the operator does this by observation. By contrast a car's cruise control uses closed-loop feedback, which classifies it as a servomechanism. A data frame with 167 observations on 5 variables, 4 nominal and 1 as the target class.
#
#   This data set is from a simulation of a servo system involving a servo amplifier, a motor, a lead screw/nut, and a sliding carriage of some sort. It may have been on of the translational axes of a robot on the 9th floor of the Al lab. In any case, the output value is almost certainly a rise time, or the time required for the system to respond to a step change in a position set point.
#
#   The variables that describe the data set and their values are the following:
#
# Motor A,B,C,D,E
#
# Screw A,B,C,D,E
#
# Pgain 3,4,5,6
#
# Vgain 1,2,3,4,5
#
# Class 0.13 to 7.10

# %% [markdown]
# ---

# %% [markdown]
# # **What is Linear Regression?**
#
# Linear regression is a type of supervised machine learning algorithm that computes the linear relationship between the dependent variable and one or more independent features by fitting a linear equation to observed data.
#
# When there is only one independent feature, it is known as Simple Linear Regression, and when there are more than one feature, it is known as Multiple Linear Regression.
#
# Similarly, when there is only one dependent variable, it is considered Univariate Linear Regression, while when there are more than one dependent variables, it is known as Multivariate Regression.

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # **Import CSV as Dataframe**

# %% [markdown]
# # **Using URL of file directly**

# %%
df = pd.read_csv(r'https://github.com/YBI-Foundation/Dataset/raw/main/Servo%20Mechanism.csv')

# %% [markdown]
# # **Get the first five rows of dataframe**

# %%
df.head()
# Out:
#   Motor Screw  Pgain  Vgain  Class
# 0     E     E      5      4      4
# 1     B     D      6      5     11
# 2     D     D      4      3      6
# 3     B     A      3      2     48
# 4     D     B      6      5      6
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Pgain'].plot(kind='hist', bins=20, title='Pgain')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Vgain'].plot(kind='hist', bins=20, title='Vgain')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Class'].plot(kind='hist', bins=20, title='Class')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('Motor').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Screw').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Pgain', y='Vgain', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Vgain', y='Class', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7['Pgain'].plot(kind='line', figsize=(8, 4), title='Pgain')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8['Vgain'].plot(kind='line', figsize=(8, 4), title='Vgain')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['Class'].plot(kind='line', figsize=(8, 4), title='Class')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Screw'].value_counts()
#     for x_label, grp in _df_10.groupby('Motor')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Motor')
# _ = plt.ylabel('Screw')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_11['Motor'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_11, x='Pgain', y='Motor', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_12['Screw'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_12, x='Pgain', y='Screw', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_13['Motor'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_13, x='Vgain', y='Motor', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_14['Screw'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_14, x='Vgain', y='Screw', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# # **Get information of dataframe**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Motor   167 non-null    object
#  1   Screw   167 non-null    object
#  2   Pgain   167 non-null    int64
#  3   Vgain   167 non-null    int64
#  4   Class   167 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 6.6+ KB

# %% [markdown]
# # **Get the summary statistics**

# %%
df.describe()
# Out:
#             Pgain       Vgain       Class
# count  167.000000  167.000000  167.000000
# mean     4.155689    2.538922   21.173653
# std      1.017770    1.369850   13.908038
# min      3.000000    1.000000    1.000000
# 25%      3.000000    1.000000   10.500000
# 50%      4.000000    2.000000   18.000000
# 75%      5.000000    4.000000   33.500000
# max      6.000000    5.000000   51.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['Pgain'].plot(kind='hist', bins=20, title='Pgain')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['Vgain'].plot(kind='hist', bins=20, title='Vgain')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['Class'].plot(kind='hist', bins=20, title='Class')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_18.plot(kind='scatter', x='Pgain', y='Vgain', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19.plot(kind='scatter', x='Vgain', y='Class', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_20['Pgain'].plot(kind='line', figsize=(8, 4), title='Pgain')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21['Vgain'].plot(kind='line', figsize=(8, 4), title='Vgain')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22['Class'].plot(kind='line', figsize=(8, 4), title='Class')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_23['Pgain'].plot(kind='hist', bins=20, title='Pgain')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['Vgain'].plot(kind='hist', bins=20, title='Vgain')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25['Class'].plot(kind='hist', bins=20, title='Class')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_26.groupby('index').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_27.plot(kind='scatter', x='Pgain', y='Vgain', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28.plot(kind='scatter', x='Vgain', y='Class', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_29['Pgain'].plot(kind='line', figsize=(8, 4), title='Pgain')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_30['Vgain'].plot(kind='line', figsize=(8, 4), title='Vgain')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_31['Class'].plot(kind='line', figsize=(8, 4), title='Class')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_32['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_32, x='Pgain', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_33['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_33, x='Vgain', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_34['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_34, x='Class', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# # **Get columns names**

# %%
df.columns
# Out:
# Index(['Motor', 'Screw', 'Pgain', 'Vgain', 'Class'], dtype='object')

# %% [markdown]
# # **Get shape of dataframe**

# %%
df.shape
# Out:
# (167, 5)

# %% [markdown]
# # **Get categories and counts of categorial variables**

# %%
df[['Motor']].value_counts()
# Out:
# Motor
# C        40
# A        36
# B        36
# E        33
# D        22
# Name: count, dtype: int64

# %% [markdown]
# # **Get encoding of categorial features**

# %%
df.replace({'Motor' : {'A':0, 'B':1, 'C':2, 'D':3, 'E':4}},inplace=True)

# %%
df.replace({'Screw' : {'A':0, 'B':1, 'C':2, 'D':3, 'E':4}},inplace=True)

# %% [markdown]
# # **Defining y(dependent or label or target variable) and X (independent or features or attribute variable)**

# %%
y = df['Class']

# %%
y.shape
# Out:
# (167,)

# %%
y
# Out:
# 0       4
# 1      11
# 2       6
# 3      48
# 4       6
#        ..
# 162    44
# 163    40
# 164    25
# 165    44
# 166    20
# Name: Class, Length: 167, dtype: int64

# %%
X = df[['Motor', 'Screw', 'Pgain', 'Vgain']]

# %% [markdown]
# # **or use .drop function to define X**

# %%
X = df.drop('Class', axis=1)

# %%
X.shape
# Out:
# (167, 4)

# %%
X
# Out:
#      Motor  Screw  Pgain  Vgain
# 0        4      4      5      4
# 1        1      3      6      5
# 2        3      3      4      3
# 3        1      0      3      2
# 4        3      1      6      5
# ..     ...    ...    ...    ...
# 162      1      2      3      2
# 163      1      4      3      1
# 164      2      3      4      3
# 165      0      1      3      2
# 166      0      0      6      5
#
# [167 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# X['Motor'].plot(kind='hist', bins=20, title='Motor')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# X['Screw'].plot(kind='hist', bins=20, title='Screw')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# X['Pgain'].plot(kind='hist', bins=20, title='Pgain')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# X['Vgain'].plot(kind='hist', bins=20, title='Vgain')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# X.plot(kind='scatter', x='Motor', y='Screw', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# X.plot(kind='scatter', x='Screw', y='Pgain', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# X.plot(kind='scatter', x='Pgain', y='Vgain', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# X['Motor'].plot(kind='line', figsize=(8, 4), title='Motor')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# X['Screw'].plot(kind='line', figsize=(8, 4), title='Screw')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# X['Pgain'].plot(kind='line', figsize=(8, 4), title='Pgain')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# X['Vgain'].plot(kind='line', figsize=(8, 4), title='Vgain')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# # **Get train test split**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state=2529)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((116, 4), (51, 4), (116,), (51,))

# %% [markdown]
# # **Get model train**

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # **Get model prediction**

# %%
y_pred = lr.predict(X_test)

# %%
y_pred.shape
# Out:
# (51,)

# %%
y_pred
# Out:
# array([24.55945258, 30.98765106, 18.54485477, 25.51524243, 38.56082023,
#        23.52007775, 11.61947065, 20.03335614, 40.60404401, 41.7009556 ,
#        13.66269443, 26.01242807, 16.50163099, 16.54663453, 21.92598051,
#        22.52570646, -5.46449561, 30.68912392, 32.7323477 ,  1.41282941,
#        33.97718702, 31.63543611, 33.52806048, 30.04133887, 19.38557109,
#         6.49364826, 28.5528375 , 17.04382017, 25.06611589,  3.50411229,
#        30.59606128, 23.67067716, 35.72188367, 32.08456265, 12.46018697,
#         3.6547117 , 23.47201865, 33.03087484, 17.49294672, 37.61450804,
#        27.54898855, 22.07657992, 11.51387478,  9.470651  , 30.53852451,
#        28.64590014, 33.67865989,  4.60102388, 24.1198037 , 21.13026773,
#        25.71390094])

# %% [markdown]
# # **Get model evaluation**

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 66.03589175595563

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 7.190539677251235

# %% [markdown]
# # **Get visualization of actual vs predicted reluts**

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.show()

# %%
plt.xlabel("Actual")
# Out:
# Text(0.5, 0, 'Actual')

# %%
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.show()

# %% [markdown]
# # **Get future predictions**

# %% [markdown]
# Lets select randor sample from existing datset as new value
#
#
# *   Extract a random row using sample function
# *   Separate X and y
# *   Standardize X
# *   Predict

# %%
X_new = df.sample(1)

# %%
X_new
# Out:
#     Motor  Screw  Pgain  Vgain  Class
# 84      4      0      6      5     13
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_35.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Motor']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Motor'}, axis=1)
#               .sort_values('Motor', ascending=True))
#   xs = counted['Motor']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_36.sort_values('Motor', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Motor')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Screw']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Screw'}, axis=1)
#               .sort_values('Screw', ascending=True))
#   xs = counted['Screw']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_37.sort_values('Screw', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Screw')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Pgain']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Pgain'}, axis=1)
#               .sort_values('Pgain', ascending=True))
#   xs = counted['Pgain']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_38.sort_values('Pgain', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Pgain')
# _ = plt.ylabel('count()')

# %%
X_new.shape
# Out:
# (1, 5)

# %%
X_new = X_new.drop('Class', axis = 1)

# %%
X_new
# Out:
#     Motor  Screw  Pgain  Vgain
# 84      4      0      6      5
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
X_new.shape
# Out:
# (1, 4)

# %%
y_pred_new = lr.predict(X_new)

# %%
y_pred_new
# Out:
# array([6.49364826])

# %% [markdown]
# # **EXPLAINATION**
#
# Linear regression is used in many different fields, including finance, economics, and psychology, to understand and predict the behavior of a particular variable. For example, in finance, linear regression might be used to understand the relationship between a company’s stock price and its earnings or to predict the future value of a currency based on its past performance.
#
# Linear regression is a fundamental machine learning algorithm that has been widely used for many years due to its simplicity, interpretability, and efficiency. It is a valuable tool for understanding relationships between variables and making predictions in a variety of applications.
#
# However, it is important to be aware of its limitations, such as its assumption of linearity and sensitivity to multicollinearity. When these limitations are carefully considered, linear regression can be a powerful tool for data analysis and prediction.

# %% [markdown]
# ---
#
#
#
# ---
